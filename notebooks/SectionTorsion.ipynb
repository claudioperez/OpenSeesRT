# %% [markdown]
# # Torsion Constant

# %%
from opensees.section import patch, section, layer, torsion

# %%
b, d = 1.5, 1
scale = 2
sect = patch.RegularPolygon(8, d)

# sect = section.FiberSection(areas=[
#     patch.rect(vertices=[[-b/2,-d/2],[b/2,d/2]])
# ])
# sect = patch.circ(extRad=b)

#--------------------------
# d = 16
# scale=0.1
# sect = section.FiberSection(areas=[
#     patch.rect(corners=[[-8,  0],[-4, 16]]),
#     patch.rect(corners=[[ 4,  0],[ 8, 16]]),
#     patch.rect(corners=[[-4, 12],[4, 16]])
# ])

# %%
mesh = section.sect2gmsh(sect, [d/8]*2)

# %%
torsion.plot(mesh, torsion.solve_torsion(sect, mesh), scale=scale, show_edges=True)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# /home/claudio/mambaforge/envs/py39/lib/python3.9/site-packages/opensees/section/torsion.py:308: PyVistaDeprecationWarning: `panel` backend is deprecated and is planned for future removal.
#   pv.set_jupyter_backend("panel")
# MESA-LOADER: failed to open zink: /usr/lib/dri/zink_dri.so: undefined symbol: amdgpu_va_get_start_addr (search paths /usr/lib/dri, suffix _dri)
# ERROR:root:Cannot create GLX context.  Aborting.
